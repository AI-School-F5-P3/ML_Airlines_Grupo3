# %% [markdown]
# # **1.Importaciones Bàsicas**

# %%
#importacion de librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **2.DataSet para implementar**

# %% [markdown]
# **2.1 Carga del fichero**

# %%
#crear dataframe, leer archivo csv
Airline = pd.read_csv('airline_passenger_satisfaction.csv')
Airline.head() #mostrar las 5 primeras filas
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
#contamos columnas y filas
Airline.shape
# Out:
# (103904, 25)

# %%
Airline.info() #info de cada una de las columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
Airline.describe() #describe el numero de elementos de cada columna y fila
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %% [markdown]
# # **3.limpieza de datos**

# %%
Airline.columns #comprobamos los nombres ded las columnas
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
#revisamos la cantidad de clientes satisfechos, que sera nuestra variable dependiente y para posterior entrenamiento y test
Airline.satisfaction.value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: count, dtype: int64

# %%
#comprobar el nombre de las columnas
Airline.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
#revisamos el dataframe
Airline.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
#Exclusión de Columnas Irrelevantes que no se usaran para la verificacion de satisfaccion, a menos que se pida un caso aislado por cliente
#'Unnamed: 0', 'id'
Airline.drop(['Unnamed: 0', 'id'],axis=1, inplace=True)

# %%
Airline.isnull() #muestra los datos nulos como booleanos
# Out:
#         Gender  Customer Type    Age  Type of Travel  Class  Flight Distance  \
# 0        False          False  False           False  False            False
# 1        False          False  False           False  False            False
# 2        False          False  False           False  False            False
# 3        False          False  False           False  False            False
# 4        False          False  False           False  False            False
# ...        ...            ...    ...             ...    ...              ...
# 103899   False          False  False           False  False            False
# 103900   False          False  False           False  False            False
# 103901   False          False  False           False  False            False
# 103902   False          False  False           False  False            False
# 103903   False          False  False           False  False            False
#
# ...

# %%
#verificar si hay datos nulos
sns.heatmap(Airline.isnull())
# Out:
# <Axes: >

# %%
#revisamos el dataframe
Airline.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
# codificamos la columna satisfaction
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
Airline['satisfaction'] = label_encoder.fit_transform(Airline['satisfaction'])

# %%
#revisamos la correlacion de ambas columnas

correlation = Airline[['Arrival Delay in Minutes', 'satisfaction']].corr()
print(correlation)
# Out:
#                           Arrival Delay in Minutes  satisfaction
# Arrival Delay in Minutes                  1.000000     -0.057582
# satisfaction                             -0.057582      1.000000

# %%
print(Airline['Arrival Delay in Minutes'].isna().sum())  # Verifica cuántos NaNs hay
# Out:
# 310

# %%
# Calcular la mediana de la columna
mediana_retraso = Airline['Arrival Delay in Minutes'].median()

# Imputar los valores NaN con la mediana
Airline['Arrival Delay in Minutes'].fillna(mediana_retraso, inplace=True)

# %%
# Verificar los resultados
print("\nDatos después de imputar NaN:")
print(Airline)
# Out:
# Datos después de imputar NaN:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# ...

# %%
#con el mapa de calor confirmamos que ya no hay valores nulos
Airline.isnull()
sns.heatmap(Airline.isnull())
# Out:
# <Axes: >

# %%
Airline
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# ...

# %%
# Limpiar nombres de columnas para eliminar espacios en blanco
Airline.columns = Airline.columns.str.strip()

# %%
#cambiemos datos categoricos (Gender, Customer Type) por binarios para facilitar el Uso de Modelo, evitar interpretaciones erròneas
#Usar map para convertir 'Male' a 0 y 'Female' a 1
Airline['Gender'] = Airline['Gender'].map({'Male': 0, 'Female': 1})

# %%
#Usar map para convertir 'Loyal' a 1 y 'disloyal' a 0
Airline['Customer Type'] = Airline['Customer Type'].map({'Loyal Customer': 1, 'disloyal Customer': 0})

# %%
#atraves de un histograma comprobamos que solo existian dos etiquetas para tipo de cliente
Airline['Customer Type'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Eliminar espacios en blanco al principio y al final, y convertir a minúsculas
Airline['Type of Travel'] = Airline['Type of Travel'].str.strip().str.lower()

# Verificar los valores únicos después de la limpieza
print("Valores únicos después de la limpieza:", Airline['Type of Travel'].unique())

# Cambiar datos categóricos con valores limpios
Airline['Type of Travel'] = Airline['Type of Travel'].map({'business travel': 1, 'personal travel': 0})

# Verificar el resultado del mapeo
print(Airline[['Type of Travel']].head())
# Out:
# Valores únicos después de la limpieza: ['personal travel' 'business travel']
#    Type of Travel
# 0               0
# 1               1
# 2               1
# 3               1
# 4               1

# %%
# Ver todas las columnas de tipo 'object', para comprobar si falta alguna por estandarizar
categorial_columns = Airline.select_dtypes(include=['object']).columns
print(categorial_columns)
# Out:
# Index(['Class'], dtype='object')

# %%
# Verificar el resultado del mapeo
Airline[['Type of Travel']].head()
# Out:
#    Type of Travel
# 0               0
# 1               1
# 2               1
# 3               1
# 4               1

# %%
Airline.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel     Class  Flight Distance  \
# 0       0              1   13               0  Eco Plus              460
# 1       0              0   25               1  Business              235
# 2       1              1   26               1  Business             1142
# 3       1              1   25               1  Business              562
# 4       0              1   61               1  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# ...

# %%
# Ver todas las columnas de tipo 'object'
categorial_columns = Airline.select_dtypes(include=['object']).columns
print(categorial_columns)
# Out:
# Index(['Class'], dtype='object')

# %%
#cambiar a valores numericos
#'Class'

#importamos el modulo label encoder para convertir valores categoricos a numericos
from sklearn.preprocessing import LabelEncoder


# Crear un codificador de etiquetas
label_encoder_class = LabelEncoder()
# Codificar la columna 'Class' donde 'business class': 2, 'eco': 1, 'eco plus': 0
Airline['Class'] = label_encoder_class.fit_transform(Airline['Class'])

#puedes imprimir  el mapeo de categorías a valores numéricos para referencia
Mapeo_de_Class = {'business class': 2, 'eco': 1, 'eco plus': 0}
Mapeo_de_Class
# Out:
# {'business class': 2, 'eco': 1, 'eco plus': 0}

# %%
#verificamos el dataframe
Airline.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       0              1   13               0      2              460
# 1       0              0   25               1      0              235
# 2       1              1   26               1      0             1142
# 3       1              1   25               1      0              562
# 4       0              1   61               1      0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# ...

# %%
Airline['Age'].unique()
# Out:
# array([13, 25, 26, 61, 47, 52, 41, 20, 24, 12, 53, 33, 45, 38,  9, 17, 43,
#        58, 23, 57, 49, 36, 22, 31, 15, 35, 67, 37, 40, 34, 39, 50, 29, 54,
#        21, 28, 27, 69, 60, 48, 59, 46, 30, 66, 64, 44, 51, 32, 19, 42, 16,
#        11, 62,  8, 56, 68, 55, 18, 65, 72, 70, 63, 10,  7, 14, 80, 74, 71,
#        85, 73, 76, 77, 75, 79, 78])

# %%
Airline.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
Airline.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       0              1   13               0      2              460
# 1       0              0   25               1      0              235
# 2       1              1   26               1      0             1142
# 3       1              1   25               1      0              562
# 4       0              1   61               1      0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# ...

# %% [markdown]
# # A partir de aqui hacemos la tipificacion sobre los datos limpios**

# %%
Airline_clean = pd.read_csv('airline_clean_data.csv')
Airline_clean
# Out:
#         Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0            0              1   13               0      2              460
# 1            0              0   25               1      0              235
# 2            1              1   26               1      0             1142
# 3            1              1   25               1      0              562
# 4            0              1   61               1      0              214
# ...        ...            ...  ...             ...    ...              ...
# 103899       1              0   23               1      1              192
# 103900       0              1   49               1      0             2347
# 103901       0              0   30               1      0             1995
# 103902       1              0   22               1      1             1000
# 103903       0              1   27               1      0             1723
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# ...

# %%
# Información general
Airline_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  int64
#  1   Customer Type                      103904 non-null  int64
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  int64
#  4   Class                              103904 non-null  int64
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
# ...

# %% [markdown]
# # **Preprocesamiento**

# %%
Airline_clean = pd.read_csv ('airline_clean_data.csv')

# %%
Airline_clean.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
#importamos el modulo de estandarizacion
from sklearn.preprocessing import StandardScaler

# %%
# definir las columnas a normalizar
colum_normal = (['Age',
       'Flight Distance', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
       ])

# %%
print("\nRango de 'Age' antes de la normalización:")
print(Airline_clean['Age'].min(), Airline_clean['Age'].max())
scaler = StandardScaler()
# Aplicar el scaler
Airline_clean[colum_normal ] = scaler.fit_transform(Airline_clean[colum_normal ])

print("\nRango de 'Age' después de la normalización:")
print(Airline_clean['Age'].min(), Airline_clean['Age'].max())
# Out:
# Rango de 'Age' antes de la normalización:
# 7 85
#
# Rango de 'Age' después de la normalización:
# -2.142238825522583 3.0182350531236466

# %%
# Crear el scaler
scaler = StandardScaler()

# Aplicar el scaler a las columnas seleccionadas
Airline_clean[colum_normal] = scaler.fit_transform(Airline_clean[colum_normal])

# %%
# Mostrar el DataFrame con las columnas tipificadas
print("\nDataFrame con columnas tipificadas:")
Airline_clean
# Out:
# DataFrame con columnas tipificadas:
#         Gender  Customer Type       Age  Type of Travel  Class  \
# 0            0              1 -1.745279               0      2
# 1            0              0 -0.951360               1      0
# 2            1              1 -0.885200               1      0
# 3            1              1 -0.951360               1      0
# 4            0              1  1.430397               1      0
# ...        ...            ...       ...             ...    ...
# 103899       1              0 -1.083680               1      1
# 103900       0              1  0.636478               1      0
# 103901       0              0 -0.620561               1      0
# 103902       1              0 -1.149840               1      1
# 103903       0              1 -0.819040               1      0
#
#         Flight Distance  Inflight wifi service  \
# 0             -0.731539               0.203579
# 1             -0.957184               0.203579
# ...

# %%
# Guardar el DataFrame preprocesado en un archivo CSV.
Airline_clean.to_csv('airline_passenger_satisfaction_model.csv', index=False)

# %%
Airline_clean ['Flight Distance']
# Out:
# 0        -0.731539
# 1        -0.957184
# 2        -0.047584
# 3        -0.629246
# 4        -0.978244
#             ...
# 103899   -1.000307
# 103900    1.160869
# 103901    0.807860
# 103902   -0.189991
# 103903    0.535081
# Name: Flight Distance, Length: 103904, dtype: float64

# %% [markdown]
# # **Visualizaciòn**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear el gráfico de dispersión con línea de regresión
plt.figure(figsize=(10, 6))
sns.regplot(x='Arrival Delay in Minutes', y='satisfaction', data=Airline_clean, logistic=True, scatter_kws={'alpha':0.5}, line_kws={"color":"red"})
plt.title('Relación entre Arrival Delay in Minutes y Satisfacción')
plt.xlabel('Arrival Delay in Minutes')
plt.ylabel('Satisfacción')
plt.grid(True)
plt.show()

# %% [markdown]
# En este gráfico, podemos ver una línea de regresión logística ajustada (en rojo), que muestra la relación entre el retraso en la llegada y la satisfacción.
#
# La forma descendente de la curva indica que, a medida que aumenta el retraso en minutos, la probabilidad de que los pasajeros estén satisfechos disminuye de manera significativa.
#
# Esto refleja una correlación negativa entre estas dos variables,
#
# **Análisis:**
# Forma de la Curva: La curva tiene una forma característica de regresión logística, donde el descenso es más pronunciado al principio y luego se aplana. Esto significa que, para retrasos pequeños, la satisfacción disminuye rápidamente, pero a partir de cierto punto, incluso grandes aumentos en el retraso no parecen reducir tanto la satisfacción (probablemente porque ya es extremadamente baja).
#
# **Intervalo de Confianza:** El área sombreada alrededor de la línea roja representa el intervalo de confianza. Esto indica la incertidumbre en la estimación de la regresión logística, y puedes ver que la predicción se vuelve más incierta para los valores más extremos de retraso.
#
# Este gráfico es útil para visualizar el impacto del retraso en la llegada sobre la satisfacción de los pasajeros y cómo esta relación no es lineal, sino que sigue una tendencia logística.

# %%
correlation = Airline_clean[['Arrival Delay in Minutes', 'satisfaction']].corr()
print(correlation)

# Volvemos a Crear el gráfico de dispersión con línea de regresión
plt.figure(figsize=(10, 6))
sns.regplot(x='Arrival Delay in Minutes', y='satisfaction', data=Airline_clean, logistic=True, scatter_kws={'alpha':0.5}, line_kws={"color":"red"})
plt.title('Relación entre Arrival Delay in Minutes y Satisfacción')
plt.xlabel('Arrival Delay in Minutes')
plt.ylabel('Satisfacción')
plt.grid(True)
plt.show()
# Out:
#                           Arrival Delay in Minutes  satisfaction
# Arrival Delay in Minutes                  1.000000     -0.057435
# satisfaction                             -0.057435      1.000000

# %%
# Usar un estilo de ejes con ticks para gráficos limpios
with sns.axes_style(style='ticks'):
    # Crear gráfico de conteo para 'satisfaction' por 'Gender'
    g1 = sns.catplot(
        x="satisfaction",
        col="Gender",
        data=Airline,
        kind="count",
        height=2.5,
        aspect=1.0
    )
    g1.fig.suptitle("Nivel de satisfaccion segun el genero", y=1.02)  # Título para el gráfico

    g1 = sns.catplot(
        x="satisfaction",
        col="Customer Type",
        data=Airline,
        kind="count",
        height=2.5,
        aspect=1.0
    )
    g1.fig.suptitle("Nivel de satisfaccion segun el tipo de cliente ", y=1.02)

# Mostrar gráficos si estás en un script (opcional en Jupyter Notebook)
plt.show()

# %% [markdown]
# **Género:** Se observa que la distribución por género de clientes satisfechos e insatisfechos es bastante similar. Tanto para pasajeros masculinos como femeninos, no. de clientes insatisfechos son más altos que ninguno. de clientes satisfechos.
#
# **Tipo de cliente:** Los pasajeros **Loyal** son muy numerosos. Incluso entre los pasajeros **Loyal**, la proporción entre satisfechos e insatisfechos es casi de 49:51.

# %%
# Usar estilo 'white' para un diseño limpio y sin cuadrículas de fondo
with sns.axes_style('white'):
    # Crear gráfico de conteo de 'Age' con respecto a 'satisfaction'
    g = sns.catplot(
        x="Age",
        data=Airline,
        aspect=3.0,
        kind='count',
        hue='satisfaction',
        order=range(5, 80)  # Asegúrate de que las edades estén en este rango
    )

    # Ajustar las etiquetas de los ejes
    g.set_axis_labels('Age', 'Count')
    g.set_titles('Age Distribution by Passenger Satisfaction')

    # Ajustar la rotación de las etiquetas del eje X para mejor legibilidad
    plt.xticks(rotation=90)

    # Mostrar el gráfico
    plt.show()

# %% [markdown]
# Entre los **7 y los 38 años y entre los 61 y los 79 años, el cociente de pasajeros insatisfechos** es muy alto en comparación con el de pasajeros satisfechos. Por el contrario, en el rango de edad de **39 a 60 años, el cociente de pasajeros satisfechos** es mayor que el de pasajeros insatisfechos.

# %%
# Verifica si 'Flight_Distance' es una columna en Airline_clean
if 'Flight Distance' not in Airline_clean.columns:
    print("Error: 'Flight_Distance' no se encuentra en las columnas del DataFrame.")
    print("Columnas disponibles:", Airline_clean.columns)
else:
    # Aplicar un estilo 'white' para los gráficos
    with sns.axes_style('white'):
        # Crear un grid de histogramas de la distancia de vuelo por clase, tipo de viaje y satisfacción
        g = sns.FacetGrid(
            data=Airline,            # Conjunto de datos
            col="Class",                   # Crear subplots por cada clase de vuelo
            hue="satisfaction",            # Colorear los histogramas por nivel de satisfacción
            height=4.5,                    # Altura de cada subplot
            aspect=1.2,                    # Relación de aspecto de cada subplot
            palette="viridis"              # Paleta de colores para la satisfacción
        )

        # Añadir histogramas al grid
        g.map(sns.histplot, "Flight Distance", kde=True, bins=30)  # Usar KDE para suavizar la curva de distribución

        # Ajustar títulos y etiquetas
        g.set_axis_labels("Flight Distance", "Count")
        g.set_titles("Class: {col_name}")  # Título para cada subplot basado en la clase

        # Añadir una leyenda para los niveles de satisfacción
        g.add_legend(title="Satisfaction Levels")

        # Mostrar el gráfico
        plt.show()

# %% [markdown]
# **Tipo de viaje, clase, distancia del vuelo:** Para viajes de negocios en la categoría de clase ejecutiva, el número de pasajeros satisfechos es bastante mayor para distancias de vuelo más largas. Para otras combinaciones, existe una distribución casi igual de pasajeros satisfechos e insatisfechos.

# %%
print(Airline_clean.columns)
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# **Embarque en línea, conveniencia de hora de salida/llegada agrupada por clase:** para la clase Eco Plus, la hora de salida/llegada muy inconveniente (hora_de_salida/llegada_conveniente = 0) tiene un número realmente alto. de pasajeros insatisfechos, incluso cuando el embarque online se realiza muy bien. Para otras combinaciones, no. de pasajeros satisfechos están en el lado superior en comparación con el no. de pasajeros insatisfechos.

# %%
# Configuración del estilo de los ejes
with sns.axes_style(style='ticks'):
    # Crear el gráfico de conteo categórico
    g = sns.catplot(
        x="satisfaction",  # Columna de satisfacción para el eje x
        col='Ease of Online booking',  # Columna para los subgráficos
        col_wrap=6,  # Número de columnas antes de que comience una nueva fila
        data=Airline,  # DataFrame con los datos
        kind="count",  # Tipo de gráfico
        height=2.5,  # Altura de cada subgráfico
        aspect=.9  # Relación de aspecto de cada subgráfico
    )

# Mostrar el gráfico
plt.show()

# %%
# Configuración del estilo de los ejes
with sns.axes_style(style='ticks'):
    # Crear el gráfico de conteo categórico
    g = sns.catplot(
        x="satisfaction",  # Columna de satisfacción para el eje x
        col= 'Seat comfort',  # Columna para los subgráficos
        col_wrap=6,  # Número de columnas antes de que comience una nueva fila
        data=Airline,  # DataFrame con los datos
        kind="count",  # Tipo de gráfico
        height=2.5,  # Altura de cada subgráfico
        aspect=.9  # Relación de aspecto de cada subgráfico
    )

# Mostrar el gráfico
plt.show()

# %%
# Configuración del estilo de los ejes
with sns.axes_style(style='ticks'):
    # Crear el gráfico de conteo categórico
    g = sns.catplot(
        x="satisfaction",  # Columna de satisfacción para el eje x
        col= 'Cleanliness',  # Columna para los subgráficos
        col_wrap=6,  # Número de columnas antes de que comience una nueva fila
        data=Airline,  # DataFrame con los datos
        kind="count",  # Tipo de gráfico
        height=2.5,  # Altura de cada subgráfico
        aspect=.9  # Relación de aspecto de cada subgráfico
    )

# Mostrar el gráfico
plt.show()

# %%
# Configuración del estilo de los ejes
with sns.axes_style(style='ticks'):
    # Crear el gráfico de conteo categórico
    g = sns.catplot(
        x="satisfaction",  # Columna de satisfacción para el eje x
        col= 'Food and drink',  # Columna para los subgráficos
        col_wrap=6,  # Número de columnas antes de que comience una nueva fila
        data=Airline,  # DataFrame con los datos
        kind="count",  # Tipo de gráfico
        height=2.5,  # Altura de cada subgráfico
        aspect=.9  # Relación de aspecto de cada subgráfico
    )

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ***Ease of Online Booking, Seat Comfort, Cleanliness, Food and Drink: ***para todas estas características, no hay límite máximo. de los pasajeros satisfechos pertenecen a la categoría de calificadores 4 y 5. Por debajo de la calificación 4, la mayoría de los pasajeros están insatisfechos.

# %% [markdown]
# ***Checkin Service, Inflight Service, On-board Service, Leg-room Service: ***
#  Para el servicio de check-in, los que otorgan calificaciones de 0 a 2 están predominantemente insatisfechos. Para los otros tres servicios, sólo los clasificados 4 y 5 pertenecen a la categoría de pasajeros satisfechos.

# %% [markdown]
# # **Matriz de correlacion, va al final de EDA**

# %%
# Análisis de correlaciones
# Seleccionar solo las columnas numéricas para la matriz de correlación
numerical_columns_only = Airline_clean.select_dtypes(include=['int64', 'float64']).columns

plt.figure(figsize=(12, 8))
correlation_matrix = Airline_clean[numerical_columns_only].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de correlación')
plt.show()

# %%
#gráfico de barras que muestra la cuenta de observaciones en cada categoría de una variable donde Male es 1 y Female es 0
sns.countplot(x='Class', data=Airline_clean,hue = 'Gender')

# Añadir título al gráfico
plt.title('Distribución de Clase por Género')

# Nombrar los ejes
plt.xlabel('Clase')
plt.ylabel('Número de Pasajeros')

# Mostrar el gráfico
plt.show()

#mostrar analisis

print(f"Se estima que los hombres suelen viajar menos que las mujeres")
# Out:
# Se estima que los hombres suelen viajar menos que las mujeres
